# %% [markdown]
# # Introduction to Regression with Neural Networks in TensorFlow
#
# There are many definitions for a [regression problem](https://en.wikipedia.org/wiki/Regression_analysis) but in our case, we're going to simplify it to be: predicting a continuous number.
#
# For example, you might want to:
# - Predict the selling price of houses given information about them (such as number of rooms, size, number of bathrooms).
# - Predict the coordinates of a bounding box of an item in an image.
# - Predict the cost of medical insurance for an individual given their demographics (age, sex, gender, race).
#
# We're going to set the foundations for how to take a sample of inputs (this is your data), build a neural network to discover patterns in those inputs and then make a prediction (in the form of a number) based on those inputs.
#
# ## What we're going to cover
#
# Specifically, we're going to go through doing the following with TensorFlow:
# - Architecture of a regression model
# - Input shapes and output shapes
#   - `X`: features/data (inputs)
#   - `y`: labels (outputs)
# - Creating custom data to view and fit
# - Steps in modelling
#   - Creating a model
#   - Compiling a model
#     - Defining a loss function
#     - Setting up an optimizer
#     - Creating evaluation metrics
#   - Fitting a model (getting it to find patterns in our data)
# - Evaluating a model
#   - Visualizng the model
#   - Looking at training curves
#   - Compare predictions to ground truth (using our evaluation metrics)
# - Saving a model (so we can use it later)
# - Loading a model

# %% [markdown]
# ## Typical architecture of a regresison neural network
#
# Following is a generic setup for ingesting a collection of numbers, finding patterns in them and then outputing some kind of target number.
#
#
# | **Hyperparameter** | **Typical value** |
# | --- | --- |
# | Input layer shape | Same shape as number of features (e.g. 3 for # bedrooms, # bathrooms, # car spaces in housing price prediction) |
# | Hidden layer(s) | Problem specific, minimum = 1, maximum = unlimited |
# | Neurons per hidden layer | Problem specific, generally 10 to 100 |
# | Output layer shape | Same shape as desired prediction shape (e.g. 1 for house price) |
# | Hidden activation | Usually [ReLU](https://www.kaggle.com/dansbecker/rectified-linear-units-relu-in-deep-learning) (rectified linear unit) |
# | Output activation | None, ReLU, logistic/tanh |
# | Loss function | [MSE](https://en.wikipedia.org/wiki/Mean_squared_error) (mean square error) or [MAE](https://en.wikipedia.org/wiki/Mean_absolute_error) (mean absolute error)/Huber (combination of MAE/MSE) if outliers |
# | Optimizer | [SGD](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD) (stochastic gradient descent), [Adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam) |
#
#
#
# > 🔑 **Note:** A **hyperparameter** in machine learning is something a data analyst or developer can set themselves, where as a **parameter** usually describes something a model learns on its own (a value not explicitly set by an analyst).

# %%
# importing Necessary Libraries:
import os
import warnings

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # '2' means "Show me Errors only, hide Info and Warnings"
warnings.filterwarnings('ignore') # Hide the "FutureWarning" (Python logs)

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Creating Random Linear Data:

# Features / Independent Variables:
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Label / Target / Dependent Variable:
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# %%
# Visualizing Data:

plt.scatter(X, y)
plt.show()

# %% [markdown]
# #### Input shapes and output shapes
#
# One of the most important concepts when working with neural networks are the input and output shapes.
#
# The **input shape** is the shape of your data that goes into the model.
#
# The **output shape** is the shape of your data you want to come out of your model.
#
# These will differ depending on the problem you're working on.
#
# Neural networks accept numbers and output numbers. These numbers are typically represented as tensors (or arrays).
#
# Before, we created data using NumPy arrays, but we could do the same with tensors.

# %%
X = tf.constant(X)
y = tf.constant(y)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767618886.371562   44203 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9507 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# Our goal here will be to use `X` to predict `y`.
#
# So our **input** will be `X` and our **output** will be `y`.
#
# Knowing this, what do you think our input and output shapes will be?

# %%
input_shape = X[0].shape
output_shape = y[0].shape

print(input_shape, output_shape)
# Out:
# () ()

# %% [markdown]
# From this it seems our inputs and outputs have no shape?
#
# How could that be?
#
# It's because no matter what kind of data we pass to our model, it's always going to take as input and return as ouput some kind of tensor.
#
# But in our case because of our dataset (only 2 small lists of numbers), we're looking at a special kind of tensor, more specificially a rank 0 tensor or a scalar.

# %%
X[0], y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=float64, numpy=-7.0>,
#  <tf.Tensor: shape=(), dtype=float64, numpy=3.0>)

# %% [markdown]
# In our case, we're trying to build a model to predict the pattern between `X[0]` equalling `-7.0` and `y[0]` equalling `3.0`.
#
# So now we get our answer, we're trying to use 1 `X` value to predict 1 `y` value.
#
# The concepts of input and output shapes to a model are fundamental.
#
# In fact, they're probably two of the things we'll spend the most time on when we work with neural networks: **making sure your input and outputs are in the correct shape**.
#
# ![example of input and output shapes for a housing price prediction problem](https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/01-input-and-output-shapes-housing-prices.png)
# *If you were working on building a machine learning algorithm for predicting housing prices, your inputs may be number of bedrooms, number of bathrooms and number of garages, giving you an input shape of 3 (3 different features). And since you're trying to predict the price of the house, your output shape would be 1.*

# %%
X.shape
# Out:
# TensorShape([8])

# %%
X
# Out:
# <tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>

# %%
tf.reshape(X, shape= (8,1))
# Out:
# <tf.Tensor: shape=(8, 1), dtype=float64, numpy=
# array([[-7.],
#        [-4.],
#        [-1.],
#        [ 2.],
#        [ 5.],
#        [ 8.],
#        [11.],
#        [14.]])>

# %% [markdown]
# We will need to reshape X as Models in tensorflow Requires Input Dimension to be Atleast 2.

# %% [markdown]
# #### Steps in modelling
#
# Now we know what data we have as well as the input and output shapes, let's see how we'd build a neural network to model it.
#
# In TensorFlow, there are typically 3 fundamental steps to creating and training a model.
#
# 1. **Creating a model** - piece together the layers of a neural network yourself (using the [Functional](https://www.tensorflow.org/guide/keras/functional) or [Sequential API](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential)) or import a previously built model (known as transfer learning).
# 2. **Compiling a model** - defining how a models performance should be measured (loss/metrics) as well as defining how it should improve (optimizer).
# 3. **Fitting a model** - letting the model try to find patterns in the data (how does `X` get to `y`).
#
# Let's see these in action using the [Keras Sequential API](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) to build a model for our regression data. And then we'll step through each.

# %%
from tensorflow.keras import Sequential # To Create Model Using Sequential API
from tensorflow.keras.layers import Dense # To Create Dense Neurons in Network

# %%
tf.random.set_seed(42) # To Produce same results every time.

base_model = Sequential() # Creating a Sequential Model

base_model.add(Dense(units= 1)) # Adding One Dense Neuron in Model

# Compiling The Model
base_model.compile(loss= 'mae', # Mean Absolute Error
                  optimizer= 'sgd', # SGD = Stochastic Gradient Descent
                  metrics= ['mae'])

# Fitting The Model with Data
base_model.fit(tf.reshape(X, shape= (8,1)),
               y, 
               epochs= 5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 20.8303 - mae: 20.8303
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 20.4656 - mae: 20.4656
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 20.1843 - mae: 20.1843
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 19.9031 - mae: 19.9031
# I0000 00:00:1767618888.487669   44348 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 19.9031 - mae: 19.9031
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 19.6218 - mae: 19.6218

# %% [markdown]
# #### Trying to Predict value of y using our Trained Model:
#
# Keep in mind that Relationship between our Original Data is y = X + 10.

# %%
X
# Out:
# <tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>

# %%
y
# Out:
# <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>

# %%
X + 10
# Out:
# <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>

# %%
# Making a Prediction Using Trained Model:
base_model.predict(tf.constant([[17.0]])) # Because we need to pass tensor to our model.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# array([[-21.39086]], dtype=float32)

# %% [markdown]
# It doesn't go very well... it should've output something close to 27.0.
# (y = X + 10) ..> X = 17 ..> y = 27.
#
# > 🤔 **Question:** What's Keras? I thought we were working with TensorFlow but every time we write TensorFlow code, `keras` comes after `tf` (e.g. `tf.keras.layers.Dense()`)?
#
# Before TensorFlow 2.0+, [Keras](https://keras.io/) was an API designed to be able to build deep learning models with ease. Since TensorFlow 2.0+, its functionality has been tightly integrated within the TensorFlow library.

# %% [markdown]
# #### Improving a model
#
# To improve our model, we alter almost every part of the 3 steps we went through before.
#
# 1. **Creating a model** - here we might want to add more layers, increase the number of hidden units (also called neurons) within each layer, change the activation functions of each layer.
# 2. **Compiling a model** - you might want to choose optimization function or perhaps change the **learning rate** of the optimization function.
# 3. **Fitting a model** - perhaps you could fit a model for more **epochs** (leave it training for longer) or on more data (give the model more examples to learn from).

# %%
# Creating Improved Model by Increasing the Training Time (Number of Epochs):

tf.random.set_seed(42)

imprvd_model1 = Sequential()

imprvd_model1.add(Dense(units= 1))

imprvd_model1.compile(loss= 'mae',
                     optimizer= 'sgd',
                     metrics= ['mae'])

imprvd_model1.fit(tf.reshape(X, shape= (8,1)),
                 y,
                 epochs= 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 15.0451 - mae: 15.0451
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 14.8388 - mae: 14.8388
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 14.7063 - mae: 14.7063
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 14.5738 - mae: 14.5738
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 14.4413 - mae: 14.4413
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 14.3088 - mae: 14.3088
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 14.1763 - mae: 14.1763
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 14.0438 - mae: 14.0438
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 13.9113 - mae: 13.9113
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 13.7788 - mae: 13.7788
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 13.6463 - mae: 13.6463
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.5138 - mae: 13.5138
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 13.3813 - mae: 13.3813
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 13.2488 - mae: 13.2488
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 13.1163 - mae: 13.1163
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.9838 - mae: 12.9838
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.8513 - mae: 12.8513
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.7188 - mae: 12.7188
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.5863 - mae: 12.5863
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.4538 - mae: 12.4538
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 12.3213 - mae: 12.3213
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 12.1888 - mae: 12.1888
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.0563 - mae: 12.0563
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 11.9238 - mae: 11.9238
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.7913 - mae: 11.7913
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 11.6588 - mae: 11.6588
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 11.5263 - mae: 11.5263
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.3938 - mae: 11.3938
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.2613 - mae: 11.2613
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 11.1288 - mae: 11.1288
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.9963 - mae: 10.9963
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 10.8638 - mae: 10.8638
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 10.7313 - mae: 10.7313
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 10.5988 - mae: 10.5988
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 10.4663 - mae: 10.4663
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 10.3338 - mae: 10.3338
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 10.2013 - mae: 10.2013
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.0688 - mae: 10.0688
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 9.9363 - mae: 9.9363
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 9.8038 - mae: 9.8038
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 9.6713 - mae: 9.6713
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 9.5388 - mae: 9.5388
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 9.4063 - mae: 9.4063
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 9.2738 - mae: 9.2738
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 9.1413 - mae: 9.1413
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.0088 - mae: 9.0088
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 8.8763 - mae: 8.8763
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 8.7438 - mae: 8.7438
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 8.6113 - mae: 8.6113
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 8.4788 - mae: 8.4788
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 8.3463 - mae: 8.3463
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.2138 - mae: 8.2138
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 8.0813 - mae: 8.0813
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.9488 - mae: 7.9488
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.8163 - mae: 7.8163
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 7.6838 - mae: 7.6838
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.5513 - mae: 7.5513
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 7.4188 - mae: 7.4188
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 7.2863 - mae: 7.2863
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 7.1538 - mae: 7.1538
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 7.0519 - mae: 7.0519
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.0462 - mae: 7.0462
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 7.0406 - mae: 7.0406
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 7.0350 - mae: 7.0350
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 7.0294 - mae: 7.0294
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 7.0238 - mae: 7.0238
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.0181 - mae: 7.0181
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 7.0125 - mae: 7.0125
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.0069 - mae: 7.0069
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.0013 - mae: 7.0013
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.9956 - mae: 6.9956
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 6.9900 - mae: 6.9900
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.9844 - mae: 6.9844
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 6.9787 - mae: 6.9787
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 6.9731 - mae: 6.9731
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.9675 - mae: 6.9675
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 6.9619 - mae: 6.9619
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 6.9563 - mae: 6.9563
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.9506 - mae: 6.9506
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.9450 - mae: 6.9450
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.9394 - mae: 6.9394
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 6.9338 - mae: 6.9338
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.9281 - mae: 6.9281
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 6.9225 - mae: 6.9225
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.9169 - mae: 6.9169
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.9113 - mae: 6.9113
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.9056 - mae: 6.9056
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 6.9000 - mae: 6.9000
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 6.8944 - mae: 6.8944
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 6.8888 - mae: 6.8888
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.8831 - mae: 6.8831
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 6.8775 - mae: 6.8775
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.8719 - mae: 6.8719
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.8663 - mae: 6.8663
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 6.8606 - mae: 6.8606
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 6.8550 - mae: 6.8550
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.8494 - mae: 6.8494
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.8438 - mae: 6.8438
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.8381 - mae: 6.8381
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 6.8325 - mae: 6.8325

# %% [markdown]
# MAE is down from 19.62 (in Previuos Model) to 6.83.

# %%
# Making a Prediction using Improved Model:
imprvd_model1.predict(tf.constant([[17.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# array([[29.463106]], dtype=float32)

# %% [markdown]
# Our Prediction Should be 27.
#
# This Model is quite close to getting correct prediction than base model.

# %% [markdown]
# `Creating Improved Model by Increasing the Hidden layers, Number of Neurons and Using Activation Functions for layers:`

# %%
tf.random.set_seed(42)

imprvd_model2 = Sequential()

imprvd_model2.add(Dense(units= 10, activation= 'relu'))
imprvd_model2.add(Dense(units= 5, activation= 'relu'))
imprvd_model2.add(Dense(units= 1))

imprvd_model2.compile(loss= 'mae',
                     optimizer= 'sgd',
                     metrics= ['mae'])

imprvd_model2.fit(tf.reshape(X, shape= (8,1)),
                 y,
                 epochs= 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 14.5247 - mae: 14.5247
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 14.1589 - mae: 14.1589
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 14.0258 - mae: 14.0258
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 13.9263 - mae: 13.9263
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 13.8329 - mae: 13.8329
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 13.7673 - mae: 13.7673
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 13.7029 - mae: 13.7029
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 13.6398 - mae: 13.6398
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 13.5771 - mae: 13.5771
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 13.5191 - mae: 13.5191
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.4689 - mae: 13.4689
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 13.4369 - mae: 13.4369
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 13.4085 - mae: 13.4085
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 13.3805 - mae: 13.3805
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 13.3600 - mae: 13.3600
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.3500 - mae: 13.3500
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 13.3400 - mae: 13.3400
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 13.3300 - mae: 13.3300
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 13.3200 - mae: 13.3200
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.3100 - mae: 13.3100
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 13.3000 - mae: 13.3000
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.2900 - mae: 13.2900
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.2800 - mae: 13.2800
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 13.2700 - mae: 13.2700
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.2600 - mae: 13.2600
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 13.2500 - mae: 13.2500
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 13.2400 - mae: 13.2400
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.2300 - mae: 13.2300
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 13.2200 - mae: 13.2200
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 13.2100 - mae: 13.2100
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 13.2000 - mae: 13.2000
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 13.1900 - mae: 13.1900
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 13.1800 - mae: 13.1800
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.1700 - mae: 13.1700
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 13.1600 - mae: 13.1600
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.1500 - mae: 13.1500
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 13.1400 - mae: 13.1400
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ -2s -2419656us/step - loss: 13.1300 - mae: 13.1300
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 13.1200 - mae: 13.1200
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 13.1100 - mae: 13.1100
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 13.1000 - mae: 13.1000
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 13.0900 - mae: 13.0900
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 13.0800 - mae: 13.0800
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 13.0700 - mae: 13.0700
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 13.0600 - mae: 13.0600
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.0500 - mae: 13.0500
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 13.0400 - mae: 13.0400
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.0300 - mae: 13.0300
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 13.0200 - mae: 13.0200
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.0100 - mae: 13.0100
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 13.0000 - mae: 13.0000
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.9900 - mae: 12.9900
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.9800 - mae: 12.9800
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.9700 - mae: 12.9700
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.9600 - mae: 12.9600
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 12.9500 - mae: 12.9500
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.9400 - mae: 12.9400
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.9300 - mae: 12.9300
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.9200 - mae: 12.9200
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.9100 - mae: 12.9100
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.9000 - mae: 12.9000
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.8900 - mae: 12.8900
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.8800 - mae: 12.8800
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.8700 - mae: 12.8700
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.8600 - mae: 12.8600
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.8500 - mae: 12.8500
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 12.8400 - mae: 12.8400
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 12.8300 - mae: 12.8300
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 12.8200 - mae: 12.8200
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.8100 - mae: 12.8100
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.8000 - mae: 12.8000
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.7900 - mae: 12.7900
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.7800 - mae: 12.7800
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.7700 - mae: 12.7700
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.7600 - mae: 12.7600
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.7500 - mae: 12.7500
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.7400 - mae: 12.7400
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 12.7300 - mae: 12.7300
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.7200 - mae: 12.7200
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 12.7100 - mae: 12.7100
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.7000 - mae: 12.7000
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.6900 - mae: 12.6900
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.6800 - mae: 12.6800
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.6700 - mae: 12.6700
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.6600 - mae: 12.6600
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 12.6500 - mae: 12.6500
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.6400 - mae: 12.6400
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 12.6300 - mae: 12.6300
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.6200 - mae: 12.6200
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 12.6100 - mae: 12.6100
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 12.6000 - mae: 12.6000
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 12.5900 - mae: 12.5900
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.5800 - mae: 12.5800
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.5700 - mae: 12.5700
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.5600 - mae: 12.5600
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.5500 - mae: 12.5500
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.5400 - mae: 12.5400
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.5300 - mae: 12.5300
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 12.5200 - mae: 12.5200
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 12.5100 - mae: 12.5100

# %%
# Making a Prediction using Improved Model:
imprvd_model2.predict(tf.constant([[17.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# array([[0.99999934]], dtype=float32)

# %% [markdown]
# `Creating Improved Model by Changing the Optimizer and Adjusting Learning Rate:`

# %%
tf.random.set_seed(42)

imprvd_model3 = Sequential()

imprvd_model3.add(Dense(units= 10, activation= 'relu'))
imprvd_model3.add(Dense(units= 5, activation= 'relu'))
imprvd_model3.add(Dense(units= 1))

imprvd_model3.compile(loss= 'mae',
                     optimizer= tf.keras.optimizers.Adam(learning_rate= 0.01),
                     metrics= ['mae'])

imprvd_model3.fit(tf.reshape(X, shape= (8,1)),
                 y,
                 epochs= 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 12.1075 - mae: 12.1075
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 11.8253 - mae: 11.8253
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 11.5319 - mae: 11.5319
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 11.2268 - mae: 11.2268
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 10.9105 - mae: 10.9105
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 10.5781 - mae: 10.5781
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 10.2600 - mae: 10.2600
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.9909 - mae: 9.9909
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 9.7081 - mae: 9.7081
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 9.4062 - mae: 9.4062
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.0861 - mae: 9.0861
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.7476 - mae: 8.7476
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.3879 - mae: 8.3879
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.0068 - mae: 8.0068
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.6014 - mae: 7.6014
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.1720 - mae: 7.1720
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6.7173 - mae: 6.7173
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 6.2319 - mae: 6.2319
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 5.7204 - mae: 5.7204
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 5.1786 - mae: 5.1786
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4.6028 - mae: 4.6028
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 3.9942 - mae: 3.9942
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 3.6800 - mae: 3.6800
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 3.5991 - mae: 3.5991
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 3.7051 - mae: 3.7051
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.7972 - mae: 3.7972
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 4.0143 - mae: 4.0143
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.1922 - mae: 4.1922
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 4.2983 - mae: 4.2983
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 4.3355 - mae: 4.3355
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4.3159 - mae: 4.3159
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 4.2455 - mae: 4.2455
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4.1323 - mae: 4.1323
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 3.9803 - mae: 3.9803
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3.7974 - mae: 3.7974
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3.5906 - mae: 3.5906
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.4864 - mae: 3.4864
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.3992 - mae: 3.3992
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 3.3186 - mae: 3.3186
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 3.2370 - mae: 3.2370
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3.1552 - mae: 3.1552
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.2041 - mae: 3.2041
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 3.2159 - mae: 3.2159
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 3.1797 - mae: 3.1797
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 3.1369 - mae: 3.1369
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.0647 - mae: 3.0647
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.9764 - mae: 2.9764
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2.8973 - mae: 2.8973
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2.8959 - mae: 2.8959
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 2.8813 - mae: 2.8813
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8537 - mae: 2.8537
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.8163 - mae: 2.8163
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.7681 - mae: 2.7681
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2.7107 - mae: 2.7107
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.6448 - mae: 2.6448
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 2.6271 - mae: 2.6271
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2.6027 - mae: 2.6027
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2.5434 - mae: 2.5434
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.4614 - mae: 2.4614
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.4239 - mae: 2.4239
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2.3742 - mae: 2.3742
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2.3127 - mae: 2.3127
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2.2330 - mae: 2.2330
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 2.1744 - mae: 2.1744
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2.0764 - mae: 2.0764
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2.0208 - mae: 2.0208
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.9581 - mae: 1.9581
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.8992 - mae: 1.8992
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8339 - mae: 1.8339
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.7531 - mae: 1.7531
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.7125 - mae: 1.7125
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.6221 - mae: 1.6221
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.5369 - mae: 1.5369
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.4656 - mae: 1.4656
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.3783 - mae: 1.3783
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.2738 - mae: 1.2738
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.1533 - mae: 1.1533
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.1061 - mae: 1.1061
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.0042 - mae: 1.0042
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.8404 - mae: 0.8404
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.7559 - mae: 0.7559
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.7564 - mae: 0.7564
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.6202 - mae: 0.6202
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3908 - mae: 0.3908
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4889 - mae: 0.4889
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.2866 - mae: 0.2866
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.4752 - mae: 0.4752
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5788 - mae: 0.5788
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3382 - mae: 0.3382
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4609 - mae: 0.4609
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.6401 - mae: 0.6401
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.6250 - mae: 0.6250
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.4434 - mae: 0.4434
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.4090 - mae: 0.4090
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5021 - mae: 0.5021
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2954 - mae: 0.2954
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3816 - mae: 0.3816
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4157 - mae: 0.4157
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2856 - mae: 0.2856
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2764 - mae: 0.2764

# %%
# Making a Prediction Using Improved Model:
imprvd_model3.predict(tf.constant([[17.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# array([[27.024652]], dtype=float32)

# %% [markdown]
# This Model is Quite Improved compared to All Previous Ones.

# %% [markdown]
# #### Evaluating a model
#
# A typical workflow we'll go through when building neural networks is:
#
# ```
# Build a model -> evaluate it -> build (tweak) a model -> evaulate it -> build (tweak) a model -> evaluate it...
# ```
#
# The tweaking comes from maybe not building a model from scratch but adjusting an existing one.
#
#
# When it comes to evaluation, you'll want to remember the words: "visualize, visualize, visualize."
#
# This is because you're probably better looking at something (doing) than you are thinking about something.
#
# It's a good idea to visualize:
# * **The data** - what data are you working with? What does it look like?
# * **The model itself** - what does the architecture look like? What are the different shapes?
# * **The training of a model** - how does a model perform while it learns?
# * **The predictions of a model** - how do the predictions of a model line up against the ground truth (the original labels)?
#
# Let's start by visualizing the model.
#
# But first, we'll create a little bit of a bigger dataset and a new model we can use.

# %% [markdown]
# Making a Bigger Dataset:

# %%
# Features:
X = tf.range(start= -100,
            limit= 100,
            delta= 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
# Like Our last Data, We will follow same Pattern for Creating Label: y = X+10:

y = X + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
print(X.ndim, X.shape)
# Out:
# 1 (50,)

# %%
# Reshaping X so that it has 2 Dimensions:
X = tf.reshape(X, shape= (50,1))

# %%
print(X.ndim, X.shape)
# Out:
# 2 (50, 1)

# %% [markdown]
# #### Split data into training/test set
#
# One of the other most common and important steps in a machine learning project is creating a training and test set (and when required, a validation set).
#
# Each set serves a specific purpose:
# * **Training set** - the model learns from this data, which is typically 70-80% of the total data available (like the course materials you study during the semester).
# * **Validation set** - the model gets tuned on this data, which is typically 10-15% of the total data available (like the practice exam you take before the final exam).
# * **Test set** - the model gets evaluated on this data to test what it has learned, it's typically 10-15% of the total data available (like the final exam you take at the end of the semester).
#
# For now, we'll just use a training and test set, this means we'll have a dataset for our model to learn on as well as be evaluated on.
#
# We can create them by splitting our `X` and `y` arrays.
#
# > 🔑 **Note:** When dealing with real-world data, this step is typically done right at the start of a project (the test set should always be kept separate from all other data). We want our model to learn on training data and then evaluate it on test data to get an indication of how well it **generalizes** to unseen examples.

# %%
print(len(X), len(y))
# Out:
# 50 50

# %%
# Splitting Data and labels into Training and Test Data:

X_train = X[:40, :]
y_train = y[:40]

X_test = X[40:, :]
y_test = y[40:]

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (TensorShape([40, 1]),
#  TensorShape([10, 1]),
#  TensorShape([40]),
#  TensorShape([10]))

# %%
# Visualizing Training and Test Data:

plt.scatter(X_train, y_train, c= 'blue', label= 'Training Data')
plt.scatter(X_test, y_test, c= 'red', label= 'Test Data')
plt.legend()
plt.show()

# %% [markdown]
# #### Visualizing the model
#
# After you've built a model, you might want to take a look at it (especially if you haven't built many before).
#
# You can take a look at the layers and shapes of your model by calling [`summary()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#summary) on it.
#
# > 🔑 **Note:** Visualizing a model is particularly helpful when you run into input and output shape mismatches.

# %%
# Building a Model:

tf.random.set_seed(42)
model= Sequential()
model.add(Dense(units= 1))
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate= 0.1),
             loss= 'mae',
             metrics= ['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# To get a Proper Model Summary, we either have to Fit the Model with some data, or we can provide "input_shape" in first layer of the Model.

# %%
# Building Same Model with "input_shape" argument in first Layer:

tf.random.set_seed(42)
model= Sequential()
model.add(Dense(units= 1, input_shape= [1,]))
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate= 0.1),
             loss= 'mae',
             metrics= ['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Calling `summary()` on our model shows us the layers it contains, the output shape and the number of parameters.
# * **Total params** - total number of parameters in the model.
# * **Trainable parameters** - these are the parameters (patterns) the model can update as it trains.
# * **Non-trainable parameters** - these parameters aren't updated during training (this is typical when you bring in the already learned patterns from other models during transfer learning).
#
# > 📖 **Resource:** For a more in-depth overview of the trainable parameters within a layer, check out [MIT's introduction to deep learning video](https://youtu.be/njKP3FqW3Sk).

# %%
# Training The Model:

model.fit(X_train, y_train, epochs= 100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - loss: 38.3379 - mae: 38.3379
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 29.9220 - mae: 29.9220
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 21.7218 - mae: 21.7218
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 13.9080 - mae: 13.9080
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.3824 - mae: 8.3824
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 10.4696 - mae: 10.4696
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 12.2369 - mae: 12.2369
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 12.8248 - mae: 12.8248
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 12.5123 - mae: 12.5123
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 11.4977 - mae: 11.4977
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 9.9271 - mae: 9.9271
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.9112 - mae: 7.9112
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 7.1649 - mae: 7.1649
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.4902 - mae: 8.4902
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 8.3541 - mae: 8.3541
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 7.0513 - mae: 7.0513
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.2273 - mae: 6.2273
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.7663 - mae: 6.7663
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.5132 - mae: 6.5132
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.7713 - mae: 5.7713
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 6.0179 - mae: 6.0179
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 6.0276 - mae: 6.0276
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.4220 - mae: 5.4220
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.5350 - mae: 5.5350
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.5306 - mae: 5.5306
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.9098 - mae: 4.9098
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.1560 - mae: 5.1560
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.1151 - mae: 5.1151
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.4660 - mae: 4.4660
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.8768 - mae: 4.8768
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.8543 - mae: 4.8543
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.1418 - mae: 4.1418
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.3901 - mae: 4.3901
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.2350 - mae: 4.2350
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.5880 - mae: 3.5880
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.9096 - mae: 3.9096
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.4728 - mae: 3.4728
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.3546 - mae: 3.3546
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.2053 - mae: 3.2053
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.8467 - mae: 2.8467
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.6922 - mae: 2.6922
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.6727 - mae: 2.6727
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.3909 - mae: 2.3909
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.3225 - mae: 2.3225
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.1765 - mae: 2.1765
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.9721 - mae: 1.9721
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.9847 - mae: 1.9847
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.6558 - mae: 1.6558
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.5764 - mae: 1.5764
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5361 - mae: 1.5361
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.2191 - mae: 1.2191
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.1441 - mae: 1.1441
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.9679 - mae: 0.9679
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.8347 - mae: 0.8347
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6817 - mae: 0.6817
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5591 - mae: 0.5591
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6373 - mae: 0.6373
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.7873 - mae: 0.7873
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1156 - mae: 0.1156
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2280 - mae: 0.2280
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2218 - mae: 0.2218
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5688 - mae: 0.5688
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5850 - mae: 0.5850
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3540 - mae: 0.3540
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.9466 - mae: 0.9466
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.8276 - mae: 0.8276
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6153 - mae: 0.6153
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7652 - mae: 0.7652
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.6619 - mae: 0.6619
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.4069 - mae: 0.4069
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2358 - mae: 1.2358
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2286 - mae: 0.2286
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.6229 - mae: 1.6229
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5775 - mae: 0.5775
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.7685 - mae: 1.7685
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.9311 - mae: 0.9311
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.6926 - mae: 0.6926
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2590 - mae: 0.2590
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2852 - mae: 0.2852
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5753 - mae: 0.5753
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0525 - mae: 0.0525
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3196 - mae: 0.3196
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.7090 - mae: 0.7090
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3544 - mae: 0.3544
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2732 - mae: 1.2732
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4139 - mae: 0.4139
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7468 - mae: 1.7468
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.9241 - mae: 0.9241
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5475 - mae: 0.5475
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3143 - mae: 0.3143
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1995 - mae: 0.1995
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5878 - mae: 0.5878
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2028 - mae: 0.2028
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.5677 - mae: 1.5677
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.6752 - mae: 0.6752
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.1333 - mae: 1.1333
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5036 - mae: 0.5036
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.1752 - mae: 1.1752
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4636 - mae: 0.4636
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.3536 - mae: 1.3536

# %% [markdown]
# #### Visualizing the predictions
#
# To visualize predictions, it's always a good idea to plot them against the ground truth labels.
#
# Often you'll see this in the form of `y_test` vs. `y_pred` (ground truth vs. predictions).

# %%
# Creating a Function to plot Training Data, Test Data and Predictions:

def plot_predictions(train_data,
                    train_labels,
                    test_data,
                    test_labels,
                    predictions):
    """
    Plots Training and Testing data With Predictions from Model.
    """

    plt.figure(figsize= (10,8))

    # Plotting Training Data:
    plt.scatter(train_data, train_labels, c= 'blue', label= 'Training Data')

    # Plotting Test Data:
    plt.scatter(test_data, test_labels, c= 'green', label= 'Testing Data')

    # Plotting Predictions:
    plt.scatter(test_data, predictions, c= 'red', label= 'Predictions')

    plt.legend()
    plt.show()

# %%
# Making Predictions using Trained Model:
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f1816641b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step

# %%
y_pred
# Out:
# array([[ 70.900955],
#        [ 74.961494],
#        [ 79.02203 ],
#        [ 83.08257 ],
#        [ 87.143105],
#        [ 91.20364 ],
#        [ 95.26418 ],
#        [ 99.32472 ],
#        [103.38526 ],
#        [107.4458  ]], dtype=float32)

# %%
# Plotting:

plot_predictions(train_data= X_train,
                train_labels= y_train,
                test_data= X_test,
                test_labels= y_test,
                predictions= y_pred)

# %% [markdown]
# #### Evaluating predictions
#
# Alongisde visualizations, evaulation metrics are your alternative best option for evaluating your model.
#
# Depending on the problem we're working on, different models have different evaluation metrics.
#
# Two of the main metrics used for regression problems are:
# * **Mean absolute error (MAE)** - the mean difference between each of the predictions.
# * **Mean squared error (MSE)** - the squared mean difference between of the predictions (use if larger errors are more detrimental than smaller errors).
#
# The lower each of these values, the better.
#
# You can also use [`model.evaluate()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#evaluate) which will return the loss of the model as well as any metrics setup during the compile step.

# %%
model.evaluate(x= X_test,
              y= y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 1.1734 - mae: 1.1734
# [1.173377275466919, 1.173377275466919]

# %%
# Mean Absolute Error:
mae= tf.metrics.mae(y_test, y_pred)
mae
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([0.9009552 , 0.96149445, 1.0220337 , 1.0825729 , 1.1431046 ,
#        1.2036438 , 1.264183  , 1.3247223 , 1.3852615 , 1.4458008 ],
#       dtype=float32)>

# %% [markdown]
# Huh? That's strange, MAE should be a single output.
#
# Instead, we get 10 values.
#
# This is because our `y_test` and `y_preds` tensors are different shapes.

# %%
print(y_test.shape, y_pred.shape)
# Out:
# (10,) (10, 1)

# %%
tf.squeeze(y_pred)
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([ 70.900955,  74.961494,  79.02203 ,  83.08257 ,  87.143105,
#         91.20364 ,  95.26418 ,  99.32472 , 103.38526 , 107.4458  ],
#       dtype=float32)>

# %%
mae= tf.metrics.mae(y_test, tf.squeeze(y_pred))
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.173377275466919>

# %%
# Mean Squared Error:
mse= tf.metrics.mse(y_test, tf.squeeze(y_pred))
mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.4070491790771484>
