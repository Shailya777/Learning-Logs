# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Scatter Plots

# %%
df1 = pd.read_csv("dm_office_sales.csv")

# %%
df1.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df1.shape
# Out:
# (1000, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "work experience")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "division")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level", palette = "RdYlGn")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level", size= "work experience", palette = "RdYlGn")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level", palette = "RdYlGn", s = 200)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level", palette = "RdYlGn", s = 200, alpha= 0.3)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df1, x = "salary", y = "sales", hue = "training level", palette = "RdYlGn", s = 100,
               style="level of education")
plt.show()

# %% [markdown]
#  ## Rug plot, Histogram and KDE

# %%
df1.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(10,8))
sns.rugplot(data = df1, x = "salary")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.rugplot(data = df1, x = "salary", height = 0.5, color = "red")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data = df1, x = "salary")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data = df1, x = "salary", bins = 30)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data = df1, x = "salary", bins = 30, color = "green", linewidth = 2)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.displot(data = df1, x = "salary")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.displot(data = df1, x = "salary", bins = 30, color = "red", linewidth = 3)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.displot(data = df1, x = "salary", bins = 30, kde = True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = df1, x = "salary")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = df1, x = "salary", fill = True)
plt.show()

# %%
np.random.seed(42)
uniform_distr = np.random.rand(100)

# %%
uniform_distr
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864,
#        0.15599452, 0.05808361, 0.86617615, 0.60111501, 0.70807258,
#        0.02058449, 0.96990985, 0.83244264, 0.21233911, 0.18182497,
#        0.18340451, 0.30424224, 0.52475643, 0.43194502, 0.29122914,
#        0.61185289, 0.13949386, 0.29214465, 0.36636184, 0.45606998,
#        0.78517596, 0.19967378, 0.51423444, 0.59241457, 0.04645041,
#        0.60754485, 0.17052412, 0.06505159, 0.94888554, 0.96563203,
#        0.80839735, 0.30461377, 0.09767211, 0.68423303, 0.44015249,
#        0.12203823, 0.49517691, 0.03438852, 0.9093204 , 0.25877998,
#        0.66252228, 0.31171108, 0.52006802, 0.54671028, 0.18485446,
#        0.96958463, 0.77513282, 0.93949894, 0.89482735, 0.59789998,
#        0.92187424, 0.0884925 , 0.19598286, 0.04522729, 0.32533033,
#        0.38867729, 0.27134903, 0.82873751, 0.35675333, 0.28093451,
#        0.54269608, 0.14092422, 0.80219698, 0.07455064, 0.98688694,
# ...

# %%
uniform_distr = pd.DataFrame(data = uniform_distr, columns = ["numbers"])

# %%
uniform_distr
# Out:
#      numbers
# 0   0.374540
# 1   0.950714
# 2   0.731994
# 3   0.598658
# 4   0.156019
# ..       ...
# 95  0.493796
# 96  0.522733
# 97  0.427541
# 98  0.025419
# 99  0.107891
#
# [100 rows x 1 columns]

# %%
plt.figure(figsize=(10,8))
sns.displot(data = uniform_distr, x = "numbers", kde = True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = uniform_distr, x = "numbers", fill = True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = uniform_distr, x = "numbers", fill = True , clip = [0,1])
plt.show()

# %%
np.random.seed(42)
normal_distr = np.random.randn(100)

# %%
normal_distr
# Out:
# array([ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337,
#        -0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004,
#        -0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783,
#        -0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ,
#         1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272,
#         0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375,
#        -0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491,
#        -1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124,
#         0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199,
#        -0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016,
#         0.32408397, -0.38508228, -0.676922  ,  0.61167629,  1.03099952,
#         0.93128012, -0.83921752, -0.30921238,  0.33126343,  0.97554513,
#        -0.47917424, -0.18565898, -1.10633497, -1.19620662,  0.81252582,
# ...

# %%
normal_distr = pd.DataFrame(data = normal_distr, columns = ["numbers"])

# %%
normal_distr
# Out:
#      numbers
# 0   0.496714
# 1  -0.138264
# 2   0.647689
# 3   1.523030
# 4  -0.234153
# ..       ...
# 95 -1.463515
# 96  0.296120
# 97  0.261055
# 98  0.005113
# 99 -0.234587
#
# [100 rows x 1 columns]

# %%
plt.figure(figsize=(10,8))
sns.displot(data = normal_distr, x = "numbers", kde = True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = normal_distr, x = "numbers", fill = True)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data = normal_distr, x = "numbers", fill = True, clip = [-1,1])
plt.show()

# %% [markdown]
# ## Categorical Plots - Statistics Estimation

# %%
df1.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df1["division"].value_counts()
# Out:
# division
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,8))
sns.countplot(data = df1, x = "division")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.countplot(data = df1, x = "division" , hue = "level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.countplot(data = df1, x = "level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.countplot(data = df1, x = "level of education", hue = "division")
plt.show()

# %%
df1.groupby("level of education")["salary"].mean()
# Out:
# level of education
# associate's degree    93156.410194
# bachelor's degree     94133.764706
# high school           83887.351852
# master's degree       93718.000000
# some college          88115.836735
# Name: salary, dtype: float64

# %%
plt.figure(figsize = (10,8))
sns.barplot(data = df1, x = "level of education", y = "salary", estimator = np.mean)
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(data = df1, x = "level of education", y = "salary", estimator = np.mean , errorbar = "sd")
plt.show()

# %%
df1.groupby(["level of education","division"]).mean()["salary"]
# Out:
# level of education  division
# associate's degree  computer hardware     94300.290323
#                     computer software    104628.533333
#                     office supplies       92533.787037
#                     peripherals           91789.470588
#                     printers              89151.200000
# bachelor's degree   computer hardware     92991.750000
#                     computer software    108020.888889
#                     office supplies       87330.285714
#                     peripherals           96882.826087
#                     printers              92552.000000
# high school         computer hardware     90550.315789
#                     computer software     98393.500000
#                     office supplies       81681.666667
#                     peripherals           84126.206897
#                     printers              77924.148148
# master's degree     computer hardware     96587.000000
#                     office supplies       92029.000000
# ...

# %%
plt.figure(figsize = (10,8))
sns.barplot(data = df1, x = "level of education", hue = "division", y = "salary", estimator = np.mean)
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(data = df1, x = "level of education", hue = "division", y = "salary", estimator = np.mean)

plt.legend(loc = (1.1,0.5))
plt.show()

# %% [markdown]
# ## Categorical Plots - Distribution within Categories

# %%
df2 = pd.read_csv("StudentsPerformance.csv")

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize = (10,8))
sns.boxplot(data = df2, x = "math score")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxplot(data = df2, x = "math score" , y ="parental level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxplot(data = df2, x = "math score" , y ="parental level of education" , hue = "gender")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxplot(data = df2, x = "math score" , y ="parental level of education" , hue = "gender", width = 0.5)
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender")

plt.legend(loc=(1,0.5))
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender", split = True)

plt.legend(loc=(1,0.5))
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender", split = True, 
              inner = "sticks")

plt.legend(loc=(1,0.5))
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.violinplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender", split = True, 
              inner = "quartile")

plt.legend(loc=(1,0.5))
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.swarmplot(data = df2, x = "math score")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.swarmplot(data = df2, x = "math score" , y = "parental level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.swarmplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender")
plt.show()

# %%
plt.figure(figsize = (15,12))
sns.swarmplot(data = df2, x = "math score" , y = "parental level of education", hue = "gender", dodge = True)
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxenplot(data = df2, x = "math score")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxenplot(data = df2, x = "math score", y = "parental level of education")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxenplot(data = df2, x = "math score", y = "parental level of education", hue = "gender")
plt.show()

# %% [markdown]
# ## Comparision Plots

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize= (10,8))
sns.jointplot(data = df2, x = "math score", y = "reading score")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.jointplot(data = df2, x = "math score", y = "reading score", kind = "hex")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.jointplot(data = df2, x = "math score", y = "reading score", kind = "hist")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.jointplot(data = df2, x = "math score", y = "reading score", kind = "kde")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.jointplot(data = df2, x = "math score", y = "reading score", hue = "gender")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.pairplot(data = df2)
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.pairplot(data = df2, hue = "gender")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.pairplot(data = df2, hue = "gender", diag_kind= "hist")
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.pairplot(data = df2, hue = "gender", diag_kind= "hist", corner = True)
plt.show()

# %% [markdown]
# ## Grid Plots

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize = (10,8))
sns.catplot(data = df2, x = "math score", y = "gender")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.catplot(data = df2, x = "math score", y = "gender", kind = "box")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.catplot(data = df2, x = "math score", y = "gender", kind = "box" , row = "lunch" )
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.catplot(data = df2, x = "math score", y = "gender", kind = "box" , row = "lunch" , col = "test preparation course" )
plt.show()

# %%
g = sns.FacetGrid(data = df2, row = "lunch" , col = "test preparation course")

# %%
g.map(plt.scatter, "math score", "reading score")
g.add_legend()
plt.subplots_adjust(wspace = 1.5, hspace = 1)

plt.show()

# %%
g = sns.PairGrid(df2)

# %%
g = sns.PairGrid(df2)
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)

# %%
g = sns.PairGrid(df2, hue = "gender")
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)
g.add_legend()

# %% [markdown]
# ## Matrix Plots

# %%
df3 = pd.read_csv("country_table.csv")

# %%
df3.head()
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11

# %%
df3 = df3.set_index("Countries")

# %%
df3.head()
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df3)
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df3.drop("Life expectancy", axis = 1))
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df3.drop("Life expectancy", axis = 1), annot = True)
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df3.drop("Life expectancy", axis = 1), annot = True, linewidth = 1)
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.clustermap(df3.drop("Life expectancy", axis = 1), annot = True)
plt.show()

# %%
plt.figure(figsize= (10,8))
sns.clustermap(df3.drop("Life expectancy", axis = 1), annot = True, col_cluster= False)
plt.show()
