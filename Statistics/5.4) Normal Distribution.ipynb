# %% [markdown]
# # Normal Distribution

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![Capture3.PNG](attachment:Capture3.PNG)

# %% [markdown]
# ![Capture4.PNG](attachment:Capture4.PNG)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## The Standard Normal Distribution:

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![Capture3.PNG](attachment:Capture3.PNG)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Normal Distribution Using Numpy:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Generating a Random Number Using Normal Distribution with Mean = 100, Standard Deviation = 2

# %%
np.random.normal(loc= 100, scale= 2) # loc = mean, scale = std
# Out:
# 97.42275786599616

# %%
np.random.normal(loc= 100, scale= 2)
# Out:
# 98.94309092621751

# %% [markdown]
# #### Generating 10 Random Numbers Using Normal Distribution with Mean = 100, Standard Deviation = 2

# %%
np.random.normal(loc= 100, scale= 2, size= 10)
# Out:
# array([ 99.18029455,  98.59964902,  99.19531469,  99.40367429,
#        103.38239153, 100.54109398,  99.08648816,  99.0088765 ,
#        100.23435255, 100.46430522])

# %% [markdown]
# #### Generating 1000 Random Numbers Using Normal Distribution with Mean = 100, Standard Deviation = 2 and Plotting:

# %%
normal_dist = np.random.normal(loc= 100, scale= 2, size= 1000)

sns.displot(data= normal_dist)
plt.show()

# %% [markdown]
# #### Generating 100000 Random Numbers Using Normal Distribution with Mean = 100, Standard Deviation = 2 and Plotting:

# %%
normal_dist = np.random.normal(loc= 100, scale= 2, size= 100000)

sns.displot(data= normal_dist)
plt.show()

# %% [markdown]
# ##### Checking How Many Values are Within 1 Standard Deviation of Mean:

# %%
sum((normal_dist > 98 ) & (normal_dist < 102))
# Out:
# 68145

# %% [markdown]
# ##### Checking How Many Values are Within 2 Standard Deviation of Mean:

# %%
sum((normal_dist > 96) & (normal_dist < 104))
# Out:
# 95452

# %% [markdown]
# ##### Checking How Many Values are Within 3 Standard Deviation of Mean:

# %%
sum((normal_dist > 94) & (normal_dist < 106))
# Out:
# 99737

# %% [markdown]
# ## Normal Distribution Using Scipy:

# %%
from scipy.stats import norm

# %% [markdown]
# ##### norm.cdf(x, mu, sigma): Cummulative Distribution Function:
#     For Getting Less Than or Equal to x.

# %%
norm.cdf(x= 102, loc= 100, scale= 2)
# Out:
# 0.8413447460685429

# %% [markdown]
# ##### Norm.pdf(x, mu, sigma): Probability Density Function:
#     For Getting Exact x.

# %%
norm.pdf(x= 102, loc= 100, scale= 2)
# Out:
# 0.12098536225957168

# %% [markdown]
# ##### norm.sf(x, mu, sigma): Survival Function:
#     For Getting More than x.
#     Similar to 1 - norm.cdf(x, mu, sigma)

# %%
norm.sf(x= 102, loc= 100, scale= 2)
# Out:
# 0.15865525393145707

# %%
1 - norm.cdf(x= 102, loc= 100, scale= 2)
# Out:
# 0.15865525393145707

# %% [markdown]
# ##### norm.mean(mu): Mean of The Normal Distribution:

# %%
norm.mean(loc= 100)
# Out:
# 100.0

# %% [markdown]
# ##### norm.var(mu): Variance of The Normal Distribution:

# %%
norm.var(loc= 100, scale= 2)
# Out:
# 4.0

# %% [markdown]
# ##### norm.std(loc, scale): Standard Deviation of The Normal Distribution:

# %%
norm.std(loc= 100, scale= 2)
# Out:
# 2.0

# %% [markdown]
# #### Question: Perfume bottles are filled with the average volume of 150 cc and the standard deviation of 2 cc. What percent of bottles will have a volume greater than 153 cc?
#
# mu = loc = 150
#
# sigma = scale = 2
#
# We want to Find Percentage of Bottles with Volume *More Than* 153:

# %%
norm.sf(x= 153, loc= 150, scale= 2)
# Out:
# 0.06680720126885807

# %%
1 - norm.cdf(x= 153, loc= 150, scale= 2)
# Out:
# 0.06680720126885809

# %% [markdown]
# #### Question: Perfume bottles are filled with the average volume of 150 cc and the standard deviation of 2 cc. What percent of bottles will have a volume between 148 and 152 cc?
#
# mu = loc = 150
#
# sigma = scale = 2
#
# We want to find Probability of Bottle Volume *Between 148 and 152*.
#
# So, we can find *norm.sf(148, 150, 2)* and Subtract *norm.sf(152, 150,2)* from it.
#
# OR
#
# We can find *norm.cdf(152, 150, 2)* and Subtract *norm.cdf(148, 150, 2)* from it.

# %%
norm.sf(x= 148, loc= 150, scale= 2) - norm.sf(x= 152, loc= 150, scale= 2)
# Out:
# 0.6826894921370859

# %%
norm.cdf(x= 152, loc= 150, scale= 2) - norm.cdf(x= 148, loc= 150, scale= 2)
# Out:
# 0.6826894921370859

# %% [markdown]
# ## Plotting Probability Density Function (pdf) and Cummulative Distribution Function (cdf):

# %%
# For X-Axis:
x_axis = np.linspace(144, 156, 13000)
print(x_axis)
# Out:
# [144.         144.00092315 144.0018463  ... 155.9981537  155.99907685
#  156.        ]

# %%
# For Y-Axis:
y_axis = norm.pdf(x= x_axis, loc= 150, scale= 2)
print(y_axis)
# Out:
# [0.00221592 0.00221899 0.00222207 ... 0.00222207 0.00221899 0.00221592]

# %%
sns.lineplot(x= x_axis, y= y_axis)
plt.show()

# %%
# For X-Axis:
x_axis = np.linspace(144, 156, 13000)
print(x_axis)
# Out:
# [144.         144.00092315 144.0018463  ... 155.9981537  155.99907685
#  156.        ]

# %%
# For Y-Axis:
y_axis = norm.cdf(x= x_axis, loc= 150, scale= 2)
print(y_axis)
# Out:
# [0.0013499  0.00135195 0.00135399 ... 0.99864601 0.99864805 0.9986501 ]

# %%
sns.lineplot(x= x_axis, y= y_axis)
plt.show()
