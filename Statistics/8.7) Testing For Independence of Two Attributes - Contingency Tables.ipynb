# %% [markdown]
# # Testing For Independence of Two Attributes - Contingency Tables

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ### Example:

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Contingency Tables Using Python:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

# %% [markdown]
# #### Example1:

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# H0 : There is no relationship between the row and column variables.
#
# Ha : There is a relationship.
#
# alpha = 0.05

# %%
shift_and_operator_df = pd.DataFrame(data = np.array([[22,26,23],[28,62,26],[72,22,66]]),
                                    columns= ["Operator 1", "Operator 2", "Operator 3"],
                                    index= ["Shift 1", "Shift 2", "Shift 3"])

# %%
shift_and_operator_df
# Out:
#          Operator 1  Operator 2  Operator 3
# Shift 1          22          26          23
# Shift 2          28          62          26
# Shift 3          72          22          66

# %%
chi2_contingency(observed= shift_and_operator_df)
# Out:
# Chi2ContingencyResult(statistic=50.09315721064659, pvalue=3.4527076339398545e-10, dof=4, expected_freq=array([[24.96253602, 22.50720461, 23.53025937],
#        [40.78386167, 36.77233429, 38.44380403],
#        [56.25360231, 50.7204611 , 53.0259366 ]]))

# %% [markdown]
# alpha = 0.05
#
# p-Value = 0.0000... < alpha
#
# **We can Reject The Null Hypothesis.**

# %% [markdown]
# #### Example2:

# %% [markdown]
# In Tips Dataset from Seaborn Library, Check if There is a relationship between Smoking Habit and Day of the Week.
#
# H0 : There is No Relationship Between Smoking Habits and Days of the Weeks.
#
# Ha: There is a Relationship Between Smoking Habit and Days of Weeks.
#
# alpha = 0.05

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
smk_and_days = pd.pivot_table(data = tips, index= "day", columns= "smoker", aggfunc= "count", observed= False)["tip"]

# %%
smk_and_days
# Out:
# smoker  Yes  No
# day
# Thur     17  45
# Fri      15   4
# Sat      42  45
# Sun      19  57

# %%
chi2_contingency(observed= smk_and_days)
# Out:
# Chi2ContingencyResult(statistic=25.787216672396262, pvalue=1.0567572499836523e-05, dof=3, expected_freq=array([[23.63114754, 38.36885246],
#        [ 7.24180328, 11.75819672],
#        [33.15983607, 53.84016393],
#        [28.96721311, 47.03278689]]))

# %% [markdown]
# alpha = 0.05
#
# p_Value = 0.000... < alpha
#
# **We Can Reject The Null Hypothesis.**
